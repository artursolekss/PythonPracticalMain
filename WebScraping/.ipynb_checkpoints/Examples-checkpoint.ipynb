# %%
# import requests

# response = requests.get("https://www.ecb.europa.eu/home/html/index.en.html")

# %%
from bs4 import BeautifulSoup

# soup = BeautifulSoup(response.content,"html.parser")

with open("European Central Bank.html","r",encoding="utf8") as f:
    data_html = f.read()
    
soup = BeautifulSoup(data_html,"html.parser")

# %%
# with open("testpage.html","w",encoding="utf8") as f:
#     f.write(str(soup))

# %%
inflation_element = soup.find(class_="ecb-inflationData cf")

# %%
# inflation_elements = inflation_element.children 1st option
inflation_elements = inflation_element.find_all(class_="item")

# %%
data = dict()

# for inflation_data_element in inflation_elements:
#     print("Inflation on " + inflation_data_element.find(class_="ecb-small").text + " is " +
#           inflation_data_element.text.split("%")[0] + "%")

for inflation_data_element in inflation_elements:
    month = inflation_data_element.find(class_="ecb-small").text
    value = inflation_data_element.text.split("%")[0]
    data[month] = value

# %%
import pandas as pnd

# %%
df = pnd.DataFrame({"Month":data.keys(),"Inflation (%)":data.values()})

# %%
df
# Out:
#               Month Inflation (%)
# 0       January '23           8.6
# 1      February '23           8.5
# 2  March '23 (Est.)           6.9

# %%
with open("TestData.html","r",encoding="utf8") as f:
    html_content = f.read()

# %%
soup = BeautifulSoup(html_content,"html.parser")

# %%
table_html_element = soup.find("table")

# %%
table_head = table_html_element.find("thead")

# %%
html_header_rows = table_head.find_all("tr")
date_h = html_header_rows[0].find("th").text

# %%
html_tab_columns = html_header_rows[1].find_all("th")

# %%
columns_names = list()
for html_col in html_tab_columns:
    columns_names.append(html_col.text)

# %%
rows_html = table_html_element.find("tbody").find_all("tr")

# %%
row_names = list()

# %%
rows = list()

# %%
for row_html in rows_html:
    row_names.append(row_html.find("th").text.replace("..",""))
    columns_row = list()
    rows.append(columns_row)
    columns_html = row_html.find_all("td")
    for column_html in columns_html:
        columns_row.append(int(column_html.text.replace(",","").replace(" ","")))

# %%
df = pnd.DataFrame(rows,columns=columns_names,index=row_names)

# %%
df
# Out:
#                            19 years and less  20–24 years  25–29 years  \
# TOTAL                                   9019        45845        60890
# With income                             8579        43370        55226
# less than 200.00                        1151         1643         1206
# 200.01-400.00                           1429         2633         1714
# 400.01-700.00                           2685         8413         6768
# 700.01-1000.00                          1814         9573         8213
# 1000.01-1500.00                         1227        12921        15363
# 1500.01-2000.00                          207         5167        10594
# 2000.01-2500.00                           44         1696         5051
# 2500.01-3000.00                            9          672         2600
# 3000.01-4000.00                           10          428         2231
# 4000.01-5000.00                            0          140          818
# 5000.01-6000.00                            1           45          328
# above 6000.00                              2           39          340
# With minimum wage or less               4458         9701         7191
# With minimum wage                        186         1036         1370
# Employees without income                 440         2475         5664
#
#                            30–34 years  35–39 years  40–44 years  45–49 years  \
# TOTAL                            93470       103214        90494        90794
# With income                      84202        95521        86159        87364
# less than 200.00                  1782         1870         1747         1951
# 200.01-400.00                     2546         2792         2465         2681
# 400.01-700.00                    10818        13224        12812        14401
# 700.01-1000.00                   12175        14065        13554        15516
# 1000.01-1500.00                  20576        23084        20489        21186
# 1500.01-2000.00                  14413        15804        13597        13171
# 2000.01-2500.00                   8313         8956         7906         6940
# 2500.01-3000.00                   4932         5240         4380         3827
# 3000.01-4000.00                   4532         5081         4351         3642
# 4000.01-5000.00                   2040         2486         2165         1821
# 5000.01-6000.00                    958         1263         1136          859
# above 6000.00                     1117         1656         1557         1369
# With minimum wage or less        11252        13097        12352        13660
# With minimum wage                 2669         3750         3686         4394
# Employees without income          9268         7693         4335         3430
#
#                            50–54 years  55–59 years  60–64 years  65–69 years  \
# TOTAL                            90248        85241        78814        35978
# With income                      86494        81391        74722        33307
# less than 200.00                  2072         2140         2564         3384
# 200.01-400.00                     2896         3295         3687         3270
# 400.01-700.00                    16625        17447        17392         8240
# 700.01-1000.00                   17019        17779        17176         6967
# 1000.01-1500.00                  21864        20659        18262         6310
# 1500.01-2000.00                  12094        10132         8370         2638
# 2000.01-2500.00                   5678         4375         3127         1073
# 2500.01-3000.00                   2914         2090         1598          498
# 3000.01-4000.00                   2682         1817         1299          473
# 4000.01-5000.00                   1231          784          601          209
# 5000.01-6000.00                    554          352          282           98
# above 6000.00                      865          521          364          147
# With minimum wage or less        15308        16304        17633        12366
# With minimum wage                 4971         5049         5222         1779
# Employees without income          3754         3850         4092         2671
#
#                            70–74 years  75 years and more  Unknown
# TOTAL                            14049               7104     7824
# With income                      12749               6269     6523
# less than 200.00                  2010               1583      433
# 200.01-400.00                     1698               1065      457
# 400.01-700.00                     3385               1562     1749
# 700.01-1000.00                    2351                949      937
# 1000.01-1500.00                   1885                629     1676
# 1500.01-2000.00                    721                212      476
# 2000.01-2500.00                    286                 92      256
# 2500.01-3000.00                    148                 65      173
# 3000.01-4000.00                    129                 47      171
# 4000.01-5000.00                     68                 26       85
# 5000.01-6000.00                     27                 15       39
# above 6000.00                       41                 24       71
# With minimum wage or less         6157               3806     2128
# With minimum wage                  752                323      633
# Employees without income          1300                835     1301

# %%
def get_age_group_data():
    age_group = input("Enter age group:\n")
    data = df.drop("TOTAL").drop("With income")[age_group]
    x = list(data.index)
    y = list(data)
    return [x,y,age_group]

# %%
x,y,age_group = get_age_group_data()
# Out:
# Enter age group:
# 20–24 years

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,label=age_group)
plt.xticks(range(len(x)),x,rotation=60)

plt.xlabel("Income")
plt.ylabel("Number of people")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
total = sum(y)
y = [100* yi/total for yi in y]

plt.plot(x,y,label=age_group)
plt.xticks(range(len(x)),x,rotation=60)

plt.xlabel("Income")
plt.ylabel("Number of people (%)")

plt.legend()
plt.show()

# %%
x,y2,age_group2 = get_age_group_data()
total = sum(y2)
y2 = [100* yi/total for yi in y2]

plt.plot(x,y,label=age_group)
plt.plot(x,y2,label=age_group2)

plt.xticks(range(len(x)),x,rotation=90)

plt.xlabel("Income")
plt.ylabel("Number of people (%)")

plt.legend()
plt.show()
# Out:
# Enter age group:
# 25–29 years

# %%
names = {1:"Arturs",2:"Jack",3:"Peter"}

# %%
df_names = pnd.DataFrame({"ID":names.keys(),"Name":names.values()})

# %%
last_names = {1:"Olekss",2:"Sparrow",3:"House"}
df_last_names = pnd.DataFrame({"ID":last_names.keys(),"Last Name":last_names.values()})

# %%
df_persons = df_names.merge(df_last_names,on="ID")

# %%
df_persons["Full Name"] = df_persons["Name"].str.cat(df_persons["Last Name"],sep=" ")

# %%
df_persons
# Out:
#    ID    Name Last Name     Full Name
# 0   1  Arturs    Olekss  ArtursOlekss
# 1   2    Jack   Sparrow   JackSparrow
# 2   3   Peter     House    PeterHouse
